# %% [raw]
# ---
# aliases:
# - /ai/2023/01/14/shap-values
# badges: true
# categories:
# - ai
# date: '2023-01-14'
# description: How SHAP values are computed, in a few simple Python lines
# output-file: 2023-01-14-shap-values.html
# publishes: true
# title: SHAP values from scratch
#
# ---

# %% [markdown]
# SHAP values are great for understanding a model. The basic logic of how they work is quite simple and worth trying to reproduce with raw Python.
#
# On a high level, the logic is the following: To get the importance of a feature, let's remove then add it back, on every sample. By checking the impact of removing/adding the feature on the prediction for that sample, we have the importance of the feature for that sample. We can then aggregate to get the feature importance overall. This is why we loop over all samples and all features in each sample below.
#
# The only thing to add is that if we just use the existing samples, we only compute the impact of removing/adding the feature when all other features of the sample are present. The point of SHAP is to perform the operation with every combination of other features removed. This is why below we compute the coalitions.

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.linear_model import LogisticRegression
from sympy.utilities.iterables import multiset_permutations
from tqdm.notebook import tqdm
from pprint import pprint
import numpy as np
from sklearn.linear_model import LinearRegression
import random

# %% [markdown]
# # 1. Loading a dataset and fitting a model

# %%
X, y = load_breast_cancer(return_X_y=True, as_frame=True)

# %%
lr = LogisticRegression(max_iter=100, verbose=0).fit(X.values, y.values)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # 2. Computing feature importance

# %% [markdown]
# ## 2.1 Creating "coalitions"
#
# Coalitions are list of 0s and 1s representing all possible combinations of features.
#
# Ideally, we would use all possible coalitions, to cover all the possible cases. In practice, extreme coalitions (mostly 1s and mostly 0s) are used. In our case, as we use pure Python, we will only consider a few coalitions.

# %% [markdown]
# This image, from the great SHAP explanation [here](https://christophm.github.io/interpretable-ml-book/shap.html#kernelshap), shows the way coalitions are used to remove features and replace them by the average values (in red)
#
# ![](https://christophm.github.io/interpretable-ml-book/images/shap-simplified-features.jpg)

# %%
coalitions = []
for i in [0,1, len(X.columns)-1, len(X.columns)]: 
  num_ones = i 
  num_zeroes = len(X.columns) - i
  coalitions += list(multiset_permutations([0] * num_zeroes + [1] * num_ones))

pd.DataFrame(coalitions).style.applymap(lambda v: 'background-color:red' if v == 1 else None)
# Out:
# <style type="text/css">
# #T_b855c_row1_col29, #T_b855c_row2_col28, #T_b855c_row3_col27, #T_b855c_row4_col26, #T_b855c_row5_col25, #T_b855c_row6_col24, #T_b855c_row7_col23, #T_b855c_row8_col22, #T_b855c_row9_col21, #T_b855c_row10_col20, #T_b855c_row11_col19, #T_b855c_row12_col18, #T_b855c_row13_col17, #T_b855c_row14_col16, #T_b855c_row15_col15, #T_b855c_row16_col14, #T_b855c_row17_col13, #T_b855c_row18_col12, #T_b855c_row19_col11, #T_b855c_row20_col10, #T_b855c_row21_col9, #T_b855c_row22_col8, #T_b855c_row23_col7, #T_b855c_row24_col6, #T_b855c_row25_col5, #T_b855c_row26_col4, #T_b855c_row27_col3, #T_b855c_row28_col2, #T_b855c_row29_col1, #T_b855c_row30_col0, #T_b855c_row31_col1, #T_b855c_row31_col2, #T_b855c_row31_col3, #T_b855c_row31_col4, #T_b855c_row31_col5, #T_b855c_row31_col6, #T_b855c_row31_col7, #T_b855c_row31_col8, #T_b855c_row31_col9, #T_b855c_row31_col10, #T_b855c_row31_col11, #T_b855c_row31_col12, #T_b855c_row31_col13, #T_b855c_row31_col14, #T_b855c_row31_col15, #T_b855c_row31_col16, #T_b855c_row31_col17, #T_b855c_row31_col18, #T_b855c_row31_col19, #T_b855c_row31_col20, #T_b855c_row31_col21, #T_b855c_row31_col22, #T_b855c_row31_col23, #T_b855c_row31_col24, #T_b855c_row31_col25, #T_b855c_row31_col26, #T_b855c_row31_col27, #T_b855c_row31_col28, #T_b855c_row31_col29, #T_b855c_row32_col0, #T_b855c_row32_col2, #T_b855c_row32_col3, #T_b855c_row32_col4, #T_b855c_row32_col5, #T_b855c_row32_col6, #T_b855c_row32_col7, #T_b855c_row32_col8, #T_b855c_row32_col9, #T_b855c_row32_col10, #T_b855c_row32_col11, #T_b855c_row32_col12, #T_b855c_row32_col13, #T_b855c_row32_col14, #T_b855c_row32_col15, #T_b855c_row32_col16, #T_b855c_row32_col17, #T_b855c_row32_col18, #T_b855c_row32_col19, #T_b855c_row32_col20, #T_b855c_row32_col21, #T_b855c_row32_col22, #T_b855c_row32_col23, #T_b855c_row32_col24, #T_b855c_row32_col25, #T_b855c_row32_col26, #T_b855c_row32_col27, #T_b855c_row32_col28, #T_b855c_row32_col29, #T_b855c_row33_col0, #T_b855c_row33_col1, #T_b855c_row33_col3, #T_b855c_row33_col4, #T_b855c_row33_col5, #T_b855c_row33_col6, #T_b855c_row33_col7, #T_b855c_row33_col8, #T_b855c_row33_col9, #T_b855c_row33_col10, #T_b855c_row33_col11, #T_b855c_row33_col12, #T_b855c_row33_col13, #T_b855c_row33_col14, #T_b855c_row33_col15, #T_b855c_row33_col16, #T_b855c_row33_col17, #T_b855c_row33_col18, #T_b855c_row33_col19, #T_b855c_row33_col20, #T_b855c_row33_col21, #T_b855c_row33_col22, #T_b855c_row33_col23, #T_b855c_row33_col24, #T_b855c_row33_col25, #T_b855c_row33_col26, #T_b855c_row33_col27, #T_b855c_row33_col28, #T_b855c_row33_col29, #T_b855c_row34_col0, #T_b855c_row34_col1, #T_b855c_row34_col2, #T_b855c_row34_col4, #T_b855c_row34_col5, #T_b855c_row34_col6, #T_b855c_row34_col7, #T_b855c_row34_col8, #T_b855c_row34_col9, #T_b855c_row34_col10, #T_b855c_row34_col11, #T_b855c_row34_col12, #T_b855c_row34_col13, #T_b855c_row34_col14, #T_b855c_row34_col15, #T_b855c_row34_col16, #T_b855c_row34_col17, #T_b855c_row34_col18, #T_b855c_row34_col19, #T_b855c_row34_col20, #T_b855c_row34_col21, #T_b855c_row34_col22, #T_b855c_row34_col23, #T_b855c_row34_col24, #T_b855c_row34_col25, #T_b855c_row34_col26, #T_b855c_row34_col27, #T_b855c_row34_col28, #T_b855c_row34_col29, #T_b855c_row35_col0, #T_b855c_row35_col1, #T_b855c_row35_col2, #T_b855c_row35_col3, #T_b855c_row35_col5, #T_b855c_row35_col6, #T_b855c_row35_col7, #T_b855c_row35_col8, #T_b855c_row35_col9, #T_b855c_row35_col10, #T_b855c_row35_col11, #T_b855c_row35_col12, #T_b855c_row35_col13, #T_b855c_row35_col14, #T_b855c_row35_col15, #T_b855c_row35_col16, #T_b855c_row35_col17, #T_b855c_row35_col18, #T_b855c_row35_col19, #T_b855c_row35_col20, #T_b855c_row35_col21, #T_b855c_row35_col22, #T_b855c_row35_col23, #T_b855c_row35_col24, #T_b855c_row35_col25, #T_b855c_row35_col26, #T_b855c_row35_col27, #T_b855c_row35_col28, #T_b855c_row35_col29, #T_b855c_row36_col0, #T_b855c_row36_col1, #T_b855c_row36_col2, #T_b855c_row36_col3, #T_b855c_row36_col4, #T_b855c_row36_col6, #T_b855c_row36_col7, #T_b855c_row36_col8, #T_b855c_row36_col9, #T_b855c_row36_col10, #T_ ...

# %% [markdown]
# ## 2.2 Computing the feature impact (simple approach)
#
# Here is the pseudo-logic
# - For every coalition
#   - For every sample in the dataset, replace "0" in coalition with average feature value for that sample
#     - For every feature of the sample
#       - Compute model score wihtout and with the feature. The difference is the impact of that feature, on that sample, for that coalition.
#
#
# Aggregate all the impacts

# %%
# We will gather all feature impacts 
feature_impacts = {col:[] for col in X.columns}

# The mean values are used for when a feature needs to be "removed"
mean_values = X.mean().values

# For each coalition we have prepared (1s and 0s)
for coalition in tqdm(pd.DataFrame(coalitions).astype(bool).values, total=len(coalitions)): 

  # For each sample in the dataset
  for sample in X.values: 

    # In the sample, replace all the '0s' of the coalition
    # with the mean of that feature
    sample_masked = sample.copy()
    sample_masked[~coalition] = mean_values[~coalition] 

    # For each feature
    for feature_idx, feature_name in enumerate(X.columns):

      # Compute the score without the feature
      sample_without_feature = sample_masked.copy()
      sample_without_feature[feature_idx] = mean_values[feature_idx]
      score_without_feature = lr.predict_proba([sample_without_feature])[0][1]

      # Compute the score with the feature
      sample_with_feature = sample_masked.copy()
      sample_with_feature[feature_idx] = sample[feature_idx]
      score_with_feature = lr.predict_proba([sample_with_feature])[0][1]

      # Store the feature impact
      feature_impacts[feature_name].append(score_with_feature - score_without_feature)
# Out:
#   0%|          | 0/62 [00:00<?, ?it/s]

# %%
pd.DataFrame(feature_impacts, columns=X.columns).head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0     0.722058     -0.126389        0.869852  -0.128361        -0.000087
# 1     0.856055     -0.060093        0.871019  -0.128904         0.000046
# 2     0.837193      0.137117        0.870927  -0.128886        -0.000052
# 3    -0.117599      0.066944       -0.126242   0.790957        -0.000182
# 4     0.851585     -0.113725        0.871053  -0.128902        -0.000016
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0         -0.003189       -0.005405            -0.001073  -3.318434e-04
# 1          0.000479        0.000049            -0.000233  -2.085911e-07
# 2         -0.001030       -0.002803            -0.000864  -1.407096e-04
# 3         -0.003304       -0.003923            -0.000616  -4.289558e-04
# 4         -0.000529       -0.002818            -0.000606   1.432269e-06
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0               -0.000017  ...      0.870383       0.780434        -0.128907
# 1                0.000007  ...      0.870042       0.188555        -0.128906
# 2                0.000003  ...      0.866727       0.008583        -0.128905
# 3               -0.000038  ...     -0.092544      -0.039935         0.412002
# 4                0.000004  ...      0.858891       0.804422        -0.128905
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0   -0.128907         -0.000214          -0.022046        -0.028566
# 1   -0.128907          0.000061           0.003977         0.002225
# 2   -0.128905         -0.000086          -0.009560        -0.012331
# 3    0.789438         -0.000554          -0.031548        -0.027105
# 4   -0.128897         -0.000036           0.002886        -0.008952
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0             -0.003150       -0.002920                -0.000195
# 1             -0.001500        0.000262                -0.000028
# 2             -0.002686       -0.001230                -0.000020
# 3             -0.002987       -0.006344                -0.000496
# 4             -0.001008        0.000934                 0.000040
#
# [5 rows x 30 columns]

# %%
pd.DataFrame(feature_impacts).abs().mean().sort_values().iloc[-10:].plot.barh(figsize=(10, 6))

# %% [markdown]
# # The method described in the SHAP paper

# %% [markdown]
# The SHAP paper gives a faster method in order to compute accurate SHAP values with a subset of coalitions.
#
# They create a linear regression for each sample, trying to match all the coalitions to the scores, in order to compute the SHAP values in one shot.

# %%
feature_impacts = []
M = len(X.columns)

# Create a big set of coalitions
coalitions_array = np.random.choice([0, 1], size=(1000, len(X.columns)))

for sample_idx in tqdm(range(len(X)), total=len(X)):
  # Apply all coalitions to sample 0 
  sample_with_missing_replaced = (coalitions_array * X.iloc[sample_idx].values) + ((1 - coalitions_array) * X.mean().values)
  # Get model predictions for all these possibilities
  predictions = lr.predict_proba(sample_with_missing_replaced)[:,0]
  # Find a linear model that matches the coalitioned features to the predictions
  linreg = LinearRegression().fit(coalitions_array, predictions)
  feature_impacts.append(linreg.coef_)

pd.DataFrame(feature_impacts, columns=X.columns).abs().mean().sort_values(ascending=True).iloc[-10:].plot.barh(figsize=(10, 6))
# Out:
#   0%|          | 0/569 [00:00<?, ?it/s]

# %% [markdown]
# # Comparing to SHAP
#
# The calculation above should get us close to the SHAP values

# %%
# %%capture
# !pip install shap

# %%
import shap
expl = shap.KernelExplainer(lambda x: lr.predict_proba(x)[:, 1], X.mean())
shap_values = expl.shap_values(X)

# %%
shap.plots.bar(shap.Explanation(shap_values, np.repeat(expl.expected_value, len(shap_values)), feature_names=X.columns))

# %% [markdown]
# It is highlighting the same set of top features as our manual method, with similar feature importance values.
#
# We would get better results if we considered more coalitions, but the problem becomes exponentially harder.

# %% [markdown]
# # Sources
#
# Some good links:
# - https://christophm.github.io/interpretable-ml-book/shap.html#kernelshap
# - https://www.telesens.co/2020/09/17/kernel-shap/
